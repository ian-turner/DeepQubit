# %%
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['text.usetex'] = True

# %%
# loading data
names = ['Matrix', 'Euler', 'Matrix + NeRF', 'Quaternion + NeRF', 'Euler + NeRF']
data = [np.loadtxt(x) for x in [
    '1q1e-2-P.txt',
    '1q1e-2-H-P.txt',
    '1q1e-2-P-L15.txt',
    '1q1e-2-Q-P-L15.txt', 
    '1q1e-2-H-P-L15.txt',
]]

# plot setup
fig, ax = plt.subplots()
ax.set_title(r'Training progress (1 qubit, $\epsilon=0.01$)')
ax.set_xlabel('Training iteration')
ax.set_ylabel('Percent of test states solved')

for (name, ys) in zip(names, data):
    ax.plot(ys, label=name)

# plot customization
ax.legend()

#plt.savefig('training1q.png')
plt.show()

# %%
# loading data
names = ['Matrix', 'Matrix + NeRF', 'Hurwitz + NeRF']
data = [np.loadtxt(x) for x in [
    '2q1e-1-P.txt',
    '2q1e-1-P-L15.txt',
    '2q1e-1-H-P-L15.txt',
]]

# plot setup
fig, ax = plt.subplots()
ax.set_title(r'Training progress (2 qubit, $\epsilon=0.1$)')
ax.set_xlabel('Training iteration')
ax.set_ylabel('Percent of test states solved')

for (name, ys) in zip(names, data):
    ax.plot(ys, label=name)

# plot customization
ax.legend()

plt.show()

# %%
# loading data
names = ['Hurwitz', 'Base']
data = [np.loadtxt(x) for x in [
    '3q5e-1-H-P-L15.txt',
    '3q5e-1-base.txt',
]]

# plot setup
fig, ax = plt.subplots()
ax.set_title(r'Training progress (3 qubit, $\epsilon=0.5$)')
ax.set_xlabel('Training iteration')
ax.set_ylabel('Percent of test states solved')

for (name, ys) in zip(names, data):
    ax.plot(ys, label=name)

# plot customization
ax.legend()

plt.show()
